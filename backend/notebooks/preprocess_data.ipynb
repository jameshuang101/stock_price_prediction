# %% [markdown]
# ##### Imports and Config

# %%
import sys
import os
import pandas as pd
import math
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime
from src.components import data_ingestion, data_transformation, model_trainer

# %%
plt.style.use("fivethirtyeight")
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
CWD_PATH = "/home/james/Projects/stock_price_prediction/"
DATA_PATH = "/home/james/Projects/stock_price_prediction/artifacts/datasets"
sys.path.append(CWD_PATH)

# %% [markdown]
# ##### Query data

# %%
AAPL = data_ingestion.get_stock_data("AAPL", start_date="2004-07-01", end_date="2024-07-01", save_as="")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
AAPL.head()
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2002-01-02  0.393750  0.416071  0.392143  0.416071  529496800
# 2002-01-03  0.410714  0.424107  0.406607  0.421071  612007200
# 2002-01-04  0.416786  0.427679  0.410536  0.423036  409976000
# 2002-01-07  0.423571  0.428571  0.406250  0.408929  444584000
# 2002-01-08  0.406250  0.411607  0.401071  0.403750  450038400

# %%
from json import loads, dumps
result = AAPL.to_json(orient="index")
parsed = loads(result)
dumps(parsed, indent=4)
# Out:
# '{\n    "1009929600000": {\n        "Open": 0.3937500119,\n        "High": 0.4160709977,\n        "Low": 0.3921430111,\n        "Close": 0.4160709977,\n        "Volume": 529496800\n    },\n    "1010016000000": {\n        "Open": 0.4107140005,\n        "High": 0.4241069853,\n        "Low": 0.406607002,\n        "Close": 0.4210709929,\n        "Volume": 612007200\n    },\n    "1010102400000": {\n        "Open": 0.4167859852,\n        "High": 0.4276790023,\n        "Low": 0.4105359912,\n        "Close": 0.4230360091,\n        "Volume": 409976000\n    },\n    "1010361600000": {\n        "Open": 0.4235709906,\n        "High": 0.4285709858,\n        "Low": 0.40625,\n        "Close": 0.4089289904,\n        "Volume": 444584000\n    },\n    "1010448000000": {\n        "Open": 0.40625,\n        "High": 0.4116069973,\n        "Low": 0.401071012,\n        "Close": 0.4037500024,\n        "Volume": 450038400\n    },\n    "1010534400000": {\n        "Open": 0.4071429968,\n        "High": 0.4094640017,\n        "Low": 0.3799999952,\n        "Close": 0.3866069913,\n        "Volume": 327835200\n    },\n    "1010620800000": {\n        "Open": 0.3789289892,\n        "High": 0.3832139969,\n        "Low": 0.3616069853,\n        "Close": 0.3791069984,\n        "Volume": 452737600\n    },\n    "1010707200000": {\n        "Open": 0.3819639981,\n        "High": 0.3899999857,\n        "Low": 0.3678570092,\n        "Close": 0.3758929968,\n        "Volume": 348801600\n    },\n    "1010966400000": {\n        "Open": 0.3751789927,\n        "High": 0.3821429908,\n        "Low": 0.3732140064,\n        "Close": 0.3776789904,\n        "Volume": 415996000\n    },\n    "1011052800000": {\n        "Open": 0.3807139993,\n        "High": 0.3885709941,\n        "Low": 0.3787499964,\n        "Close": 0.3874999881,\n        "Volume": 290320800\n    },\n    "1011139200000": {\n        "Open": 0.3823210001,\n        "High": 0.3823210001,\n        "Low": 0.3660709858,\n        "Close": 0.3710710108,\n        "Volume": 566893600\n    },\n    "1011225600000": {\n        "Open": 0.3921430111,\n        "High": 0.4060710073,\n        "Low": 0.3905360103,\n        "Close": 0.4014289975,\n        "Volume": 660576000\n    },\n    "1011312000000": {\n        "Open": 0.3928569853,\n        "High": 0.4035710096,\n        "Low": 0.3921430111,\n        "Close": 0.3958930075,\n        "Volume": 338811200\n    },\n    "1011657600000": {\n        "Open": 0.3976790011,\n        "High": 0.3994640112,\n        "Low": 0.3896430135,\n        "Close": 0.3896430135,\n        "Volume": 327314400\n    },\n    "1011744000000": {\n        "Open": 0.3892860115,\n        "High": 0.411428988,\n        "Low": 0.3855359852,\n        "Close": 0.4110710025,\n        "Volume": 443279200\n    },\n    "1011830400000": {\n        "Open": 0.4091069996,\n        "High": 0.4198209941,\n        "Low": 0.4089289904,\n        "Close": 0.4144639969,\n        "Volume": 344002400\n    },\n    "1011916800000": {\n        "Open": 0.4087499976,\n        "High": 0.4182139933,\n        "Low": 0.4046429992,\n        "Close": 0.4151790142,\n        "Volume": 185914400\n    },\n    "1012176000000": {\n        "Open": 0.4178569913,\n        "High": 0.4205360115,\n        "Low": 0.4057140052,\n        "Close": 0.4155359864,\n        "Volume": 186446400\n    },\n    "1012262400000": {\n        "Open": 0.4146429896,\n        "High": 0.4203569889,\n        "Low": 0.4080359936,\n        "Close": 0.4119639993,\n        "Volume": 240324000\n    },\n    "1012348800000": {\n        "Open": 0.4119639993,\n        "High": 0.4310710132,\n        "Low": 0.4096429944,\n        "Close": 0.4301789999,\n        "Volume": 471576000\n    },\n    "1012435200000": {\n        "Open": 0.4314289987,\n        "High": 0.4416069984,\n        "Low": 0.4305360019,\n        "Close": 0.4414289892,\n        "Volume": 468445600\n    },\n    "1012521600000": {\n        "Open": 0.4346430004,\n        "High": 0.4457139969,\n        "Low": 0.4346430004,\n         ...

# %%
macro = data_ingestion.get_macro_data("EFFR UNRATE UMCSENT", start_date="01-01-2002")

# %%
macro.head(30)
# Out:
#             EFFR  UNRATE  UMCSENT
# 2002-01-01  1.92     5.7     93.0
# 2002-01-02  1.92     5.7     93.0
# 2002-01-03  1.72     5.7     93.0
# 2002-01-04  1.61     5.7     93.0
# 2002-01-07  1.61     5.7     93.0
# 2002-01-08  1.61     5.7     93.0
# 2002-01-09  1.74     5.7     93.0
# 2002-01-10  1.81     5.7     93.0
# 2002-01-11  1.71     5.7     93.0
# 2002-01-14  1.78     5.7     93.0
# 2002-01-15  1.75     5.7     93.0
# 2002-01-16  1.69     5.7     93.0
# 2002-01-17  1.68     5.7     93.0
# 2002-01-18  1.71     5.7     93.0
# 2002-01-21  1.71     5.7     93.0
# 2002-01-22  1.84     5.7     93.0
# 2002-01-23  1.81     5.7     93.0
# 2002-01-24  1.80     5.7     93.0
# 2002-01-25  1.78     5.7     93.0
# 2002-01-28  1.79     5.7     93.0
# 2002-01-29  1.78     5.7     93.0
# 2002-01-30  1.78     5.7     93.0
# 2002-01-31  1.85     5.7     93.0
# 2002-02-01  1.77     5.7     90.7
# 2002-02-04  1.74     5.7     90.7
# 2002-02-05  1.64     5.7     90.7
# 2002-02-06  1.66     5.7     90.7
# 2002-02-07  1.74     5.7     90.7
# 2002-02-08  1.69     5.7     90.7
# 2002-02-11  1.76     5.7     90.7

# %% [markdown]
# ##### Format data for LSTM

# %%
name = "SP500"

# %%
working_df = pd.read_pickle(os.path.join(DATA_PATH, f"{name}/{name}_20y.pkl"))
# working_df["Open_dff"] = data_transformation.close_open_diff(working_df)
macro_df = pd.read_pickle(os.path.join(DATA_PATH, "macro/macro_20y.pkl"))
working_df = working_df.merge(macro_df, how="inner", left_index=True, right_index=True)

# %%
data_transformation.get_technical_indicators(working_df, inplace=True)

# %%
working_df.head()
# Out:
#                    Open         High          Low        Close      Volume  \
# 2004-07-01  1140.839966  1140.839966  1123.060059  1128.939941  1495700000
# 2004-07-02  1128.939941  1129.150024  1123.260010  1125.380005  1085000000
# 2004-07-06  1125.380005  1125.380005  1113.209961  1116.209961  1283300000
# 2004-07-07  1116.209961  1122.369995  1114.920044  1118.329956  1328600000
# 2004-07-08  1118.329956  1119.119995  1108.719971  1109.109985  1401100000
#
#             EFFR  UNRATE  UMCSENT       ^VIX   DX-Y.NYB      MACD        ATR  \
# 2004-07-01  1.40     5.5     96.7  15.200000  88.790001  0.000000  17.779907
# 2004-07-02  1.25     5.5     96.7  15.080000  87.970001  0.283984  11.614778
# 2004-07-06  1.30     5.5     96.7  16.250000  88.120003  1.234755  11.813740
# 2004-07-07  1.26     5.5     96.7  15.810000  87.650002  1.796474  10.598698
# 2004-07-08  1.26     5.5     96.7  16.200001  87.540001  2.951590  10.552867
#
#                   RSI
# 2004-07-01        NaN
# 2004-07-02  -0.000000
# 2004-07-06  -0.000000
# 2004-07-07 -19.981131
# 2004-07-08 -10.690871

# %%
working_df.drop(columns=["Open", "High", "Low"], inplace=True)

# %%
working_df.corr()
# Out:
#              Close    Volume      EFFR    UNRATE   UMCSENT      ^VIX  \
# Close     1.000000  0.145856  0.196423 -0.500507 -0.092746 -0.103582
# Volume    0.145856  1.000000 -0.297230  0.294812 -0.452644  0.663984
# EFFR      0.196423 -0.297230  1.000000 -0.567089  0.043574 -0.252733
# UNRATE   -0.500507  0.294812 -0.567089  1.000000 -0.367131  0.361199
# UMCSENT  -0.092746 -0.452644  0.043574 -0.367131  1.000000 -0.537590
# ^VIX     -0.103582  0.663984 -0.252733  0.361199 -0.537590  1.000000
# DX-Y.NYB  0.768560  0.047474  0.239582 -0.586230  0.166752 -0.094293
# MACD     -0.250057  0.191838 -0.069143 -0.026569 -0.110941  0.476199
# ATR       0.663943  0.470283  0.028163 -0.175842 -0.402976  0.519556
# RSI      -0.016256  0.005415 -0.020295  0.011561  0.014636  0.001298
#
#           DX-Y.NYB      MACD       ATR       RSI
# Close     0.768560 -0.250057  0.663943 -0.016256
# Volume    0.047474  0.191838  0.470283  0.005415
# EFFR      0.239582 -0.069143  0.028163 -0.020295
# UNRATE   -0.586230 -0.026569 -0.175842  0.011561
# UMCSENT   0.166752 -0.110941 -0.402976  0.014636
# ^VIX     -0.094293  0.476199  0.519556  0.001298
# DX-Y.NYB  1.000000 -0.066672  0.571282 -0.016216
# MACD     -0.066672  1.000000  0.300614 -0.003653
# ATR       0.571282  0.300614  1.000000 -0.009606
# RSI      -0.016216 -0.003653 -0.009606  1.000000

# %%
train_df, val_df, test_df = data_transformation.train_val_test_ordered_split(working_df)

# %%
train_df.to_pickle(os.path.join(DATA_PATH, f"{name}/train_df.pkl"))
val_df.to_pickle(os.path.join(DATA_PATH, f"{name}/val_df.pkl"))
test_df.to_pickle(os.path.join(DATA_PATH, f"{name}/test_df.pkl"))
